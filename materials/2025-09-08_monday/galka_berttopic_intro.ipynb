# %% [markdown]
# # Navigate to folder with data

# %% [markdown]
# The following code connects Google Drive to the Colab environment.
#
# After running it, Colab asks for permission to access the Drive.
#
# Once granted, the Drive is accessible at the path /content/drive.
#
# This is necessary if the dataset is stored in Google Drive rather than directly uploaded to Colab. The data in this case is stored in a folder called "topic_modelling" in the Google Drive.

# %% [markdown]
# Autorin:
# - Selina Galka

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

print(os.listdir())
# Out:
# Mounted at /content/drive
# ['.config', 'drive', 'sample_data']

# %%
# %cd /content/drive/MyDrive/topic_modelling
# Out:
# /content/drive/MyDrive/topic_modelling

# %% [markdown]
# # Prepare data

# %% [markdown]
# For this example notebook the french normalized text of the Memoirs of Countess Luise Charlotte von Schwerin has been prepared. The folder "topic_modelling" contains the text in a .txt file, whereas each paragraph of the text is delimited with "///". The text consists of around 700 paragrapsh. The following code prepares and cleans the specific text for the topic modelling. The code:
# - reads the text file (schwerin_text_paragraphs.txt).
# - Splits the text wherever /// appears (that acts as a paragraph separator).
# - Cleans each chunk: removes line breaks and special non-breaking spaces, collapses multiple spaces into one, strips leading/trailing whitespace.
# - Stores all cleaned chunks in a list called paragraphs.
# - Prints the list so you can see each cleaned paragraph.
#
# Preparing the dataset will also be the topic today in the afternoon.

# %%
import re  # Importing the regular expressions library

file_path = './schwerin_text_paragraphs.txt'

# Open the file and read the content
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Split the text by '///'
chunks = text.split('///')

# Clean each chunk by stripping whitespace and replacing special characters
paragraphs = []
for chunk in chunks:
    # Replace newline and non-breaking space characters
    clean_text = chunk.replace('\n', ' ').replace('\xa0', ' ')
    # Use regular expression to replace multiple spaces with a single space
    clean_text = re.sub(r'\s+', ' ', clean_text).strip()
    # Append the cleaned text to the list
    paragraphs.append(clean_text)

print(paragraphs)
# Out:
# ['Fürst Khevenhüller 1896', '« Histoire De la Vie de madame la comtesse de Schwerin', 'écrite par elle-même à ses enfants suivant les ordres de son directeur à Cologne »', 'Première partie', 'L’histoire de ma vie est si remarquable et si remplie d’événements, tant pour leur singularité que par le bruit que les plus considérables ont fait dans le monde, que ma curiosité m’a portée en premier lieu d’en rassembler le cours, et secondement pour qu’un jour mes chers enfants puissent être instruits par moi-même des suites malheureuses (selon le monde) que produit ordinairement une fortune éblouissante à une jeune personne élevée dans tout ce qui peut plaire à son ambition et à ses sens, suites dis-je d’autant plus dangereuses qu’elles sont imperceptibles à ceux dont l’amour-propre ferme les yeux sur leur conduite, et dont ils ne sont détrompés que par une longue expérience, d’autant plus rude à être exercée que peu de personnes ont le courage d’entreprendre le grand ouvrage de la connaissance de soi-même. Ah ! mon doux et divin Jésus, ce n’est que vos compassions et vos abondantes miséricordes qui m’y ont entraîné presque malgré moi, que de grâces n’avez-vous pas opposé à ma résistance, jusqu’à ce que vous ayez vaincu mon opiniâtreté, et vous m’ayez réduite à une entière résignation à votre volonté. Votre saint Nom en soit béni, loué et glorifié. Amen. Je puis raisonner des suites fâcheuses où la fortune et l’ambition sont le point de vue, et mes tristes réflexions peuvent servir d’exemple à ceux qui comme moi abuseront de leurs sentiments et donneront au monde ce qui n’est qu’à Dieu seul.', 'mon père perdit ma mère que j’avais un peu plus d’un an. Elle passait pour une femme du monde qui avait le plus de mérite et de vertus, et était citée partout comme un exemple à suivre. Elle était d’une dévotion extraordinaire, partageant les soins de sa maison avec ses attentions à l’Eglise, et l’amour de Dieu et du prochain était son unique étude. Ses larmes qu’elle versait en abondance sur ses enfants n’étaient que pour leur attirer la bénédiction divine et ses vœux qu’elle confiait à ses intimes amis étaient qu’elle pût avoir le bonheur de sainte Monique et que ses enfants puissent suivre les traces de saint Augustin. Étant enceinte de moi elle me donna à une de ses belles-sœurs. Prévoyant que sa vie ne serait pas longue, elle voulut me savoir entre les mains d’une dame d’un mérite consommé. Ah ! malheureuse que je suis, que j’en ai peu profité et que ma passion m’a fermé les yeux à tous ses sages avis ; ainsi pour me soustraire à tous les bonheurs mondains et périssables pour me conduire au céleste et éternel.', 'Dès que ma mère mourut, ma tante à qui j’étais promise offrit à mon père de me prendre chez elle ; mais l’affliction où il était de la perte irréparable qu’il venait de faire, fit qu’il voulut encore garder tous ses enfants pour sa consolation. Surtout puisqu’on trouvait que je lui ressemblais beaucoup. Enfin à deux ans et demi mon père vainquit sa tendresse [et] me mena chez ma tante où on me reçut avec tout le contentement possible et rien ne pouvait causer plus de joie dans cette maison. Ma tante demeurait chez sa sœur qui était une dame d’une vertu exemplaire de même que son époux. Cette famille n’avait point d’enfants, ils devinrent tous trois idolâtres de moi, et ces trois personnes si qualifiées par leur mérite et si distinguées par les vertus les plus éminentes se mirent (si j’ose me servir de cette expression) sous la tutelle d’un enfant fort gâté. J’étais dispensatrice des grâces et franc arbitre de tout ce que je jugeais ou proposais. Si par punition on me privait d’une partie de plaisir pendant une heure, toute la maison était en mouvement pour m’en obtenir de plus attirant le lendemain. Voilà à peu près mon éducation pendant les premières années de ma vie, où l’aveugle tendresse de mes parents me nourrissait de fiel et d’absinthe pour la conduite de mon cœur et de mes sens, comme il me repaissait de flatterie, de douc ...

# %% [markdown]
# # Installing BERTopic

# %% [markdown]
# This line installs BERTopic inside your Colab environment so you can use it for topic modeling.

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.17.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.5.9.post2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from bertopic) (5.1.0)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.12/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: llvmlite>0.36.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.43.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan>=0.8.29->bertopic) (1.16.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan>=0.8.29->bertopic) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=4.7.0->bertopic) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=4.7.0->bertopic) (25.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.56.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.8.0+cu126)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.34.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.15.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.1.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.8.3)
# Downloading bertopic-0.17.3-py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: bertopic
# Successfully installed bertopic-0.17.3

# %% [markdown]
# This line imports the BERTopic class from the bertopic library.

# %%
from bertopic import BERTopic
# Out:
# /usr/local/lib/python3.12/dist-packages/hdbscan/plots.py:448: SyntaxWarning: invalid escape sequence '\l'
#   axis.set_ylabel('$\lambda$ value')
# /usr/local/lib/python3.12/dist-packages/hdbscan/robust_single_linkage_.py:175: SyntaxWarning: invalid escape sequence '\{'
#   $max \{ core_k(a), core_k(b), 1/\alpha d(a,b) \}$.

# %% [markdown]
# # Create topics (Quick Start)

# %% [markdown]
# When you run topic_model = BERTopic(verbose=True, language="french"), you create a new BERTopic model instance configured for French text processing. The verbose=True option ensures that the model prints detailed progress messages during training, which helps you follow steps like dimensionality reduction, clustering, and topic extraction. Setting language="french" customizes preprocessing for the French language. This initialization doesn’t yet analyze your data—it simply prepares a French-optimized BERTopic model that you can later fit to your text.

# %%
topic_model = BERTopic(verbose=True, language="french")

# %% [markdown]
# This line takes the prepared French paragraphs, learns topics from them, assigns each paragraph to a topic, and returns both the topic labels (topics) and the confidence scores (probs).

# %%
topics, probs = topic_model.fit_transform(paragraphs)
# Out:
# 2025-09-01 11:07:40,344 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]
# 2025-09-01 11:09:01,312 - BERTopic - Embedding - Completed ✓
# 2025-09-01 11:09:01,315 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-09-01 11:09:12,874 - BERTopic - Dimensionality - Completed ✓
# 2025-09-01 11:09:12,875 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-09-01 11:09:12,909 - BERTopic - Cluster - Completed ✓
# 2025-09-01 11:09:12,922 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-09-01 11:09:13,199 - BERTopic - Representation - Completed ✓

# %% [markdown]
# - Embeddings: BERTopic starts with transforming our input documents into numerical representations. Although there are many ways this can be achieved, we typically use sentence-transformers as it is quite capable of capturing the semantic similarity between documents.
# - Dimensionality Reduction: As embeddings are often high in dimensionality, clustering becomes difficult. Therefore, dimensionality is reduced.
# - Clustering: The input embeddings are then grouped to similar embeddings to extract our topics.
# - Representation Representation is generated: human-readable topic labels by identifying representative words.

# %% [markdown]
# ## Save and load the model

# %%
topic_model.save("./schwerin_paragraphs.mm")
# Out:
# 2025-09-01 11:26:26,824 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %%
topic_model = BERTopic.load("./schwerin_paragraphs.mm")

# %% [markdown]
# ## Investigate the topics

# %% [markdown]
# topic_model.get_topic_info() returns a Pandas DataFrame that summarizes all discovered topics in your model.
#
# Each row represents one topic and contains metadata about it.
#
#  - Topic → the topic ID (an integer).
#
# - -1 means outliers (documents that didn’t fit into any topic).
#
#  - Count → how many documents were assigned to that topic.
#
#  - Name → a short descriptive label for the topic, based on its most frequent keywords.
#
#  - Representation (top words) → the key terms that define the topic.
#  - representative documents are the most characteristic texts for each discovered topic.

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count             Name  \
# 0      -1    259   -1_de_je_et_le
# 1       0    146   0_je_de_que_et
# 2       1     49   1_de_et_que_je
# 3       2     48    2_de_la_je_et
# 4       3     40   3_de_je_que_le
# 5       4     28   4_de_il_que_et
# 6       5     27  5_de_et_mon_que
# 7       6     26   6_de_je_que_il
# 8       7     22   7_je_de_que_et
# 9       8     18   8_de_et_je_que
# 10      9     17   9_de_je_il_que
#
#                                        Representation  \
# 0           [de, je, et, le, que, la, il, me, qu, en]
# 1        [je, de, que, et, me, la, le, il, vous, mon]
# 2         [de, et, que, je, me, la, le, ma, les, mon]
# 3   [de, la, je, et, que, me, le, comtesse, elle, qu]
# 4   [de, je, que, le, et, la, comte, il, en, schwe...
# 5         [de, il, que, et, le, je, qu, me, la, pour]
# 6        [de, et, mon, que, il, père, le, je, ma, me]
# 7        [de, je, que, il, le, me, la, et, comte, qu]
# 8         [je, de, que, et, le, elle, qu, me, la, il]
# 9           [de, et, je, que, le, me, il, la, qu, ne]
# 10        [de, je, il, que, et, le, vous, la, ne, qu]
#
#                                   Representative_Docs
# 0   [La Wergeau monta sur le soir dans ma chambre....
# 1   [Je me levai pour la première fois le jour de ...
# 2   [Nous arrivâmes qu’il était nuit et n’ayant pe...
# 3   [Le soir avant, la comtesse de Strattmann m’éc...
# 4   [Enfin le comte de Virmond me dit qu’il nommer...
# 5   [L’arrêt du prisonnier faisait toujours beauco...
# 6   [Le lendemain nous partîmes pour Berlin. Je fu...
# 7   [J’étais plus morte que vive à ce compliment, ...
# 8   [La Wergeau assura que si le comte de Schwerin...
# 9   [J’étais seule alors chez moi avec mes deux Ch...
# 10  [Le comte de Schwerin entra comme ces pensées ...

# %% [markdown]
# With topic_model.get_topic(8) ask BERTopic to return the keywords that define topic number 8. The output is a list of tuples, where:
#
# - The first element is a word strongly associated with the topic.
#
# - The second element is the word’s importance weight (a float, often shown as np.float64).

# %%
topic_model.get_topic(8)
# Out:
# [('fièvre', np.float64(0.03130257945088305)),
#  ('médecin', np.float64(0.02788126838891301)),
#  ('lit', np.float64(0.024938447044508146)),
#  ('peu', np.float64(0.021729053684913065)),
#  ('larmes', np.float64(0.020483938456216585)),
#  ('quand', np.float64(0.02046101105433914)),
#  ('temps', np.float64(0.020292110257655243)),
#  ('faire', np.float64(0.020066146439553224)),
#  ('fort', np.float64(0.01906686272484892)),
#  ('trouver', np.float64(0.018618880498813797))]

# %% [markdown]
# ## Finetuning the model

# %% [markdown]
# The topics contain many words that dont carry signifiant meaing. Therefore, we are finetuning the model with involving a stopword list. This code loads a custom list of stopwords from a text file and uses it in CountVectorizer to filter out common or unimportant words. By removing these stopwords, the model focuses on more meaningful terms in the text. The updated vectorizer is then passed to the topic model so that the topics are built using cleaner, more relevant words.

# %%
from sklearn.feature_extraction.text import CountVectorizer

with open('./stopwords_edited.txt', 'r') as file:
  stop_words = [word.strip() for word in file.readlines()]

vectorizer_model = CountVectorizer(stop_words=stop_words)
topic_model.update_topics(paragraphs, vectorizer_model=vectorizer_model)

# %% [markdown]
# ## Investigate the topics again

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                 Name  \
# 0      -1    259              -1_fort_faire_jour_tous
# 1       0    146              0_dieu_grand_monde_jour
# 2       1     49               1_mère_belle_tous_fort
# 3       2     48  2_comtesse_strattmann_vienne_madame
# 4       3     40          3_berlin_vienne_maison_tous
# 5       4     28                4_roi_pays_rien_point
# 6       5     27              5_père_belle_mère_tante
# 7       6     26             6_faire_dönhoff_dire_air
# 8       7     22         7_wergeau_enfants_dieu_faire
# 9       8     18             8_fièvre_médecin_lit_peu
# 10      9     17        9_temps_gouverneur_père_faire
#
#                                        Representation  \
# 0   [fort, faire, jour, tous, temps, monde, très, ...
# 1   [dieu, grand, monde, jour, catholique, dire, f...
# 2   [mère, belle, tous, fort, maison, tante, père,...
# 3   [comtesse, strattmann, vienne, madame, prince,...
# 4   [berlin, vienne, maison, tous, cour, temps, af...
# 5   [roi, pays, rien, point, empereur, fait, ex, m...
# 6   [père, belle, mère, tante, oncle, monde, abord...
# 7   [faire, dönhoff, dire, air, rien, comtesse, te...
# 8   [wergeau, enfants, dieu, faire, point, enfin, ...
# 9   [fièvre, médecin, lit, peu, larmes, quand, tem...
# 10  [temps, gouverneur, père, faire, dieu, enfant,...
#
#                                   Representative_Docs
# 0   [La Wergeau monta sur le soir dans ma chambre....
# 1   [Je me levai pour la première fois le jour de ...
# 2   [Nous arrivâmes qu’il était nuit et n’ayant pe...
# 3   [Le soir avant, la comtesse de Strattmann m’éc...
# 4   [Enfin le comte de Virmond me dit qu’il nommer...
# 5   [L’arrêt du prisonnier faisait toujours beauco...
# 6   [Le lendemain nous partîmes pour Berlin. Je fu...
# 7   [J’étais plus morte que vive à ce compliment, ...
# 8   [La Wergeau assura que si le comte de Schwerin...
# 9   [J’étais seule alors chez moi avec mes deux Ch...
# 10  [Le comte de Schwerin entra comme ces pensées ...

# %%
topic_model.get_topic(6)
# Out:
# [('berlin', np.float64(0.12049614810462303)),
#  ('père', np.float64(0.014493937897551159)),
#  ('retour', np.float64(0.01442894126547829)),
#  ('retournâmes', np.float64(0.012651324604878613)),
#  ('fille', np.float64(0.012623490203802984)),
#  ('parmi', np.float64(0.011703138126051482)),
#  ('campagne', np.float64(0.011570190533555888)),
#  ('bruit', np.float64(0.011473530990542354)),
#  ('trouverais', np.float64(0.010899826024381741)),
#  ('berlinet', np.float64(0.010436534466118936))]

# %% [markdown]
# The method get_document_info() shows how each document (in our case each paragraph) is related to the topics discovered by your topic model.
#
#  - Document → The original text snippet (or start of it) from your dataset.
#  - Topic → The numerical label of the assigned topic. A value of -1 means the paragraph was not strongly assigned to any topic (often considered an “outlier” or background).
#  - Name → The default name of the topic, usually formed from its most representative words (e.g., fort_faire_dieu_temps).
#  - CustomName → A customizable label for the topic, often derived from the top keywords but editable by the user.
#  - Representation → The list of keywords most strongly associated with the topic.
#  - Representative_Docs → Example document(s) that best represent this topic.
#  - Top_n_words → The top keywords again, but formatted differently for quick viewing.
#  - Probability → How strongly this paragraph belongs to the given topic. A value close to 1 means a strong match; 0 means weak or no match
#  - Representative_document → True if this paragraph is selected as one of the most representative documents for the topic, False otherwise.

# %%
topic_model.get_document_info(paragraphs)
# Out:
#                                               Document  Topic  \
# 0                              Fürst Khevenhüller 1896     -1
# 1    « Histoire De la Vie de madame la comtesse de ...     -1
# 2    écrite par elle-même à ses enfants suivant les...     -1
# 3                                      Première partie     -1
# 4    L’histoire de ma vie est si remarquable et si ...      0
# ..                                                 ...    ...
# 675  Jusque là, tous mes confesseurs avaient été de...     -1
# 676  J’ai écrit cette période avec plus de circonst...      0
# 677  Je crois qu’avec cette période je pourrai fini...      0
# 678                 Fini à Cologne ce 7 janvier 1731 .     -1
# 679                                                        -1
#
#                          Name  \
# 0    -1_fort_faire_dieu_temps
# 1    -1_fort_faire_dieu_temps
# 2    -1_fort_faire_dieu_temps
# 3    -1_fort_faire_dieu_temps
# 4    0_dieu_jamais_être_amour
# ..                        ...
# 675  -1_fort_faire_dieu_temps
# 676  0_dieu_jamais_être_amour
# 677  0_dieu_jamais_être_amour
# 678  -1_fort_faire_dieu_temps
# 679  -1_fort_faire_dieu_temps
#
#                                             CustomName  \
# 0    fort - faire - dieu - temps - jour - tous - mo...
# 1    fort - faire - dieu - temps - jour - tous - mo...
# 2    fort - faire - dieu - temps - jour - tous - mo...
# 3    fort - faire - dieu - temps - jour - tous - mo...
# 4    dieu - jamais - être - amour - point - toutes ...
# ..                                                 ...
# 675  fort - faire - dieu - temps - jour - tous - mo...
# 676  dieu - jamais - être - amour - point - toutes ...
# 677  dieu - jamais - être - amour - point - toutes ...
# 678  fort - faire - dieu - temps - jour - tous - mo...
# 679  fort - faire - dieu - temps - jour - tous - mo...
#
#                                         Representation  \
# 0    [fort, faire, dieu, temps, jour, tous, monde, ...
# 1    [fort, faire, dieu, temps, jour, tous, monde, ...
# 2    [fort, faire, dieu, temps, jour, tous, monde, ...
# 3    [fort, faire, dieu, temps, jour, tous, monde, ...
# 4    [dieu, jamais, être, amour, point, toutes, mon...
# ..                                                 ...
# 675  [fort, faire, dieu, temps, jour, tous, monde, ...
# 676  [dieu, jamais, être, amour, point, toutes, mon...
# 677  [dieu, jamais, être, amour, point, toutes, mon...
# 678  [fort, faire, dieu, temps, jour, tous, monde, ...
# 679  [fort, faire, dieu, temps, jour, tous, monde, ...
#
#                                    Representative_Docs  \
# 0    [Quatre joursLe troisième ou quatrième jour ap...
# 1    [Quatre joursLe troisième ou quatrième jour ap...
# 2    [Quatre joursLe troisième ou quatrième jour ap...
# 3    [Quatre joursLe troisième ou quatrième jour ap...
# 4    [J’ai écrit cette période avec plus de circons...
# ..                                                 ...
# 675  [Quatre joursLe troisième ou quatrième jour ap...
# 676  [J’ai écrit cette période avec plus de circons...
# 677  [J’ai écrit cette période avec plus de circons...
# 678  [Quatre joursLe troisième ou quatrième jour ap...
# 679  [Quatre joursLe troisième ou quatrième jour ap...
#
#                                            Top_n_words  Probability  \
# 0    fort - faire - dieu - temps - jour - tous - mo...     0.000000
# 1    fort - faire - dieu - temps - jour - tous - mo...     0.000000
# 2    fort - faire - dieu - temps - jour - tous - mo...     0.000000
# 3    fort - faire - dieu - temps - jour - tous - mo...     0.000000
# 4    dieu - jamais - être - amour - point - toutes ...     0.842525
# ..                                                 ...          ...
# 675  fort - faire - dieu - temps - jour - tous - mo...     0.000000
# 676  dieu - jamais - être - amour - point - toutes ...     0.842525
# 677  dieu - jamais - être - amour - point - toutes ...     0.768957
# 678  fort - faire - dieu - temps - jour - tous - mo...     0.000000
# 679  fort - faire - dieu - temps - jour - tous - mo...     0.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 675                    False
# 676                     True
# 677                    False
# 678                    False
# 679                    False
#
# [680 rows x 9 columns]

# %% [markdown]
# ## Visualize Topics

# %% [markdown]
# This visualization shows the top keywords for each discovered topic in the topic model.

# %%
topic_model.visualize_barchart(width=280, height=330, top_n_topics=20, n_words=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f31b8710-a50e-4ef2-bb68-6ae858f0c42d" class="plotly-graph-div" style="height:990px; width:1120px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f31b8710-a50e-4ef2-bb68-6ae858f0c42d")) {                    Plotly.newPlot(                        "f31b8710-a50e-4ef2-bb68-6ae858f0c42d",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012862105381643276,0.012869620486761121,0.012881321090896897,0.013017002473343168,0.013150320694474624,0.013594281187704522,0.013599240255790847,0.013796993499470016,0.015878478493507545,0.02525255434422851],"y":["après  ","église  ","fait  ","faire  ","dire  ","catholique  ","jour  ","monde  ","grand  ","dieu  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.014811863845514504,0.015133441632034006,0.015415554564878439,0.01622778908939713,0.01629145044961295,0.0164725634939562,0.017394998072072523,0.017768256518610002,0.02053557605928902,0.021030410020039393],"y":["toute  ","esprit  ","dieu  ","père  ","tante  ","maison  ","fort  ","tous  ","belle  ","mère  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.015462239980362032,0.015548429988247606,0.016097244254931663,0.016163119008374218,0.016844926029365707,0.01733685960913388,0.018873389473011412,0.021185365520724368,0.046417214143381,0.056555075135676286],"y":["monsieur  ","voir  ","après  ","temps  ","jour  ","prince  ","madame  ","vienne  ","strattmann  ","comtesse  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.015053121594423943,0.015258008747267713,0.015491149466253157,0.015877480926786966,0.017570809351476674,0.017707099820117787,0.01832604790897295,0.019726905919319724,0.023529569153238304,0.02644102048365631],"y":["fort  ","faire  ","fait  ","affaire  ","temps  ","cour  ","tous  ","maison  ","vienne  ","berlin  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.016575935439695124,0.01790104666897721,0.018415341243579745,0.018655331993645143,0.01923455185518541,0.0193598011899265,0.019702997870215948,0.020127121821318508,0.020347795352271318,0.030266747891201925],"y":["dieu  ","religion  ","monsieur  ","ex  ","fait  ","empereur  ","point  ","rien  ","pays  ","roi  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.017712695860564284,0.01795513943272011,0.018880515423066877,0.019235014042034256,0.019874939188425735,0.025003485435357728,0.027563713263590067,0.03173495796565589,0.03557910402136628,0.06375894214495938],"y":["lettre  ","toute  ","wesel  ","abord  ","monde  ","oncle  ","tante  ","mère  ","belle  ","père  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.01622226855851229,0.016285600857663302,0.016310611243227243,0.016634477480596276,0.018880660711900612,0.01980495524170792,0.021032363622440705,0.021581820402478708,0.02251647856870791,0.024588724113901204],"y":["répliquai  ","point  ","dieu  ","temps  ","comtesse  ","rien  ","air  ","dire  ","dönhoff  ","faire  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01680545730463655,0.016908381466674265,0.017581301574342942,0.017822074397617765,0.019646567238099964,0.02043102653052305,0.025002849993714278,0.02520968073753203,0.02605729020045133,0.04061665056403012],"y":["enfant  ","catholique  ","madame  ","voir  ","enfin  ","point  ","faire  ","dieu  ","enfants  ","wergeau  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.018618880498813797,0.01906686272484892,0.020066146439553224,0.020292110257655243,0.02046101105433914,0.02 ...

# %% [markdown]
# # Create topics with sentences as documents

# %%
path = "schwerin_sentences_school_cleaned.txt"
with open(path, "r", encoding="utf-8") as f:
    docs = [l.strip() for l in f if l.strip()]

print(f"Loaded {len(docs)} docs.")
# Out:
# Loaded 9855 docs.

# %%
topic_model_sentences = BERTopic(verbose=True, language="french")

topics, probs = topic_model_sentences.fit_transform(docs)
# Out:
# 2025-09-08 05:07:21,939 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/308 [00:00<?, ?it/s]
# 2025-09-08 05:13:51,466 - BERTopic - Embedding - Completed ✓
# 2025-09-08 05:13:51,471 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-09-08 05:14:40,867 - BERTopic - Dimensionality - Completed ✓
# 2025-09-08 05:14:40,870 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-09-08 05:14:41,432 - BERTopic - Cluster - Completed ✓
# 2025-09-08 05:14:41,456 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-09-08 05:14:41,801 - BERTopic - Representation - Completed ✓

# %%
from sklearn.feature_extraction.text import CountVectorizer

with open('./stopwords_edited.txt', 'r') as file:
  stop_words = [word.strip() for word in file.readlines()]

vectorizer_model = CountVectorizer(stop_words=stop_words)
topic_model_sentences.update_topics(docs, vectorizer_model=vectorizer_model)

# %%
topic_model_sentences.get_topic_info()
# Out:
#      Topic  Count                                 Name  \
# 0       -1   3618             -1_faire_tous_monde_dire
# 1        0   1066            0_madame_lettre_roi_faire
# 2        1    509       1_dieu_providence_divine_divin
# 3        2    379          2_prince_roi_reine_empereur
# 4        3    377              3_dame_femme_air_assura
# ..     ...    ...                                  ...
# 99      98     11  98_virmond_virmont_promener_couleur
# 100     99     11    99_daniel_auprès_eloignez_enlevée
# 101    100     10        100_fils_eau_touché_exaucâtes
# 102    101     10      101_mort_mourut_séjour_arrosant
# 103    102     10      102_mère_inspirâtes_sainte_vœux
#
#                                         Representation  \
# 0    [faire, tous, monde, dire, toute, rien, grand,...
# 1    [madame, lettre, roi, faire, maison, jour, cou...
# 2    [dieu, providence, divine, divin, doux, loué, ...
# 3    [prince, roi, reine, empereur, impératrice, pr...
# 4    [dame, femme, air, assura, peut, voulut, fort,...
# ..                                                 ...
# 99   [virmond, virmont, promener, couleur, conseill...
# 100  [daniel, auprès, eloignez, enlevée, cetave, ma...
# 101  [fils, eau, touché, exaucâtes, assoupie, brisa...
# 102  [mort, mourut, séjour, arrosant, consolaient, ...
# 103  [mère, inspirâtes, sainte, vœux, paresse, hint...
#
#                                    Representative_Docs
# 0    [Ainsi que, ma confession, quoique bonne, ne f...
# 1    [Le comte de Schwerin avait marqué au comte de...
# 2    [Dieu soit loué de ma maladie, voilà une bonne...
# 3    [De là je fus chez madame la Princesse Electri...
# 4    [Elle s’excusa extrêmement de ce qu’elle ne tr...
# ..                                                 ...
# 99   [Dès que le comte de Virmond arriva, je me mis...
# 100  [Je n’avais que Daniel à qui me confier., Je d...
# 101  [Je voulus me reposer la nuit ensuite, mais à ...
# 102  [« Oui, lui répétai-je en l’arrosant de mes la...
# 103  [Vous m’inspirâtes de l’offrir à votre sainte ...
#
# [104 rows x 5 columns]

# %% [markdown]
# ## Visuzalize

# %%
topic_model_sentences.visualize_barchart(width=280, height=330, top_n_topics=115, n_words=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0a846de8-7d9a-496a-b296-8c2baf341a9c" class="plotly-graph-div" style="height:9240px; width:1120px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a846de8-7d9a-496a-b296-8c2baf341a9c")) {                    Plotly.newPlot(                        "0a846de8-7d9a-496a-b296-8c2baf341a9c",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.005810866163395407,0.005837555866497964,0.005844866899006828,0.005891877880196361,0.005924315933240101,0.006035826356281747,0.006044892631941294,0.00660660162058452,0.0069214105543264764,0.0069411089115279595],"y":["jours  ","fort  ","après  ","dire  ","maison  ","madame  ","jour  ","faire  ","lettre  ","roi  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.006358114523456763,0.006457402854337724,0.006574351978213737,0.007293060446301828,0.00848793224680376,0.01247189049704138,0.01331123441282249,0.022233260290109694,0.046176682991023454,0.050051445657653654],"y":["ainsi  ","retour  ","établir  ","roi  ","berlinet  ","königsberg  ","cour  ","prusse  ","vienne  ","berlin  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.00844038530588756,0.008560184165011316,0.009003522297395266,0.00914016547815141,0.010094840487762692,0.010500315414386749,0.010727095835504793,0.010929684074627603,0.011480015867144186,0.011758086991410547],"y":["peut  ","faire  ","point  ","dire  ","femme  ","voulut  ","fille  ","dame  ","assura  ","air  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.016630084128771122,0.01674908641351089,0.016802273278142505,0.01715284495306427,0.02262302856638429,0.023805381853817927,0.023946766969701168,0.024957415719648324,0.026518201507880455,0.0518868287996853],"y":["volonté  ","maître  ","béni  ","grâce  ","divin  ","loué  ","gloire  ","jésus  ","doux  ","dieu  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.010388498825963844,0.011447353505512679,0.012046606527206839,0.01381618248324602,0.014734113732320498,0.018139979916439924,0.023579063686486913,0.03606530119335647,0.09391722928943373,0.143450705174333],"y":["voir  ","assemblée  ","vint  ","batthyány  ","chère  ","rabutin  ","brean  ","madame  ","comtesse  ","strattmann  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.009630820374785593,0.010149851624800324,0.010227911136608555,0.010537976803797552,0.0114040543901916,0.011743513778542384,0.013277102073532285,0.018293199586123063,0.021111189884159377,0.05120213275804086],"y":["cœur  ","seul  ","vie  ","grâce  ","amour  ","âme  ","volontés  ","providence  ","divine  ","dieu  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.01077309236450477,0.011014064683484164,0.011034235396843882,0.011397410812435713,0.013884971124423749,0.01620112404413816,0.016396159581637263,0.019478387577859396,0.06585148770077913,0.07554981543970783],"y":["amour  ","mystère  ","présent  ","monsieur  ","contre  ","maris  ","femme  ","mariage  ","époux  ","mari  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01178480894303759,0.012065874542230057,0.012404101536101221,0.012845603558544793,0.012955084233550145,0.0140247539893232,0.01426625132250014,0.01454339705701002,0.01535825889100868,0.019246484913769235],"y":["aigri  ","avoua  ","avoir  ","envoyait  ","temps  ","croire  ","voulut  ","demanda  ","fait  ","surpris  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.020394864089784106,0.021096563596019927,0.021438462725189067,0.022069684935370256,0.02 ...

# %% [markdown]
# hierarchical_topics = topic_model.hierarchical_topics(docs)

# %% [markdown]
# ## Hierarchical Topics

# %%
hierarchical_topics = topic_model_sentences.hierarchical_topics(docs)
# Out:
# 100%|██████████| 110/110 [00:00<00:00, 219.25it/s]

# %%
topic_model_sentences.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fd6a4cad-1da4-4a7a-a6fb-da2fc507952d" class="plotly-graph-div" style="height:1865px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd6a4cad-1da4-4a7a-a6fb-da2fc507952d")) {                    Plotly.newPlot(                        "fd6a4cad-1da4-4a7a-a6fb-da2fc507952d",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["catholique_catholiques_religion_citant_catholicité","","","catholique_catholiques_adorons_oui_authentique"],"x":[0.0,0.5646209624158119,0.5646209624158119,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["catholique_catholiques_invoquer_professeurs_octobreou","","","catholique_catholiques_religion_catholicité_citant"],"x":[0.0,0.7127427322853354,0.7127427322853354,0.5646209624158119],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["lecture_lettre_lu_livre_article","","","lettre_lettres_écrivis_frère_écrivit"],"x":[0.0,0.7896264074610488,0.7896264074610488,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["frère_satisfactions_efforçait_retourné_bonnes","","","père_frère_beau_confessai_pénétration"],"x":[0.0,0.7651321029639144,0.7651321029639144,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["wesel_père_retournâmes_allâmes_parents","","","famille_alliés_père_chacun_toute"],"x":[0.0,0.8891528300251685,0.8891528300251685,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["frère_père_beau_confessai_pénétration","","","wesel_père_famille_retournâmes_toute"],"x":[0.7651321029639144,0.9263061866367521,0.9263061866367521,0.8891528300251685],"xaxis":"x","y":[-60.0,-60.0,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["lettre_lecture_lu_écrivis_lettres","","","père_frère_wesel_beau_famille"],"x":[0.7896264074610488,1.0778999154165971,1.0778999154165971,0.9263061866367521],"xaxis":"x","y":[-40.0,-40.0,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["oncle_tante_cousine_belle_sœur","","","tante_belle_mère_ingratitudes_pardonner"],"x":[0.0,0.6442061165934051,0.6442061165934051,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["père_frère_lettre_wesel_lecture","","","tante_oncle_belle_mère_cousine"],"x":[1.0778999154165971,1.0963099108641683,1.0963099108641683,0.6442061165934051],"xaxis":"x","y":[-55.0,-55.0,-100.0,-100.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","text":["larmes_yeux_vinrent_retenir_répandis","","","larmes_yeux_morte_versa_torrents"],"x":[0.0,0.6655229271190561,0.6655229271190561,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","text":["lit_chambre_filles_porte_couchait","","","maison_chambre_chambres_salle_étage"],"x":[0.0,0.7460676976405719,0.7460676976405719,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["mari_époux_mariage_femme_maris","","", ...

# %%
tree = topic_model_sentences.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# .
# ├─catholique_catholiques_religion_catholicité_oui
# │    ├─■──catholique_catholiques_invoquer_professeurs_octobreou ── Topic: 89
# │    └─catholique_catholiques_religion_catholicité_citant
# │         ├─■──catholique_catholiques_religion_citant_catholicité ── Topic: 27
# │         └─■──catholique_catholiques_adorons_oui_authentique ── Topic: 48
# └─comtesse_vienne_berlin_dieu_strattmann
#      ├─berlin_vienne_larmes_cour_père
#      │    ├─tante_père_frère_lettre_oncle
#      │    │    ├─père_frère_lettre_wesel_lecture
#      │    │    │    ├─lettre_lecture_lu_écrivis_lettres
#      │    │    │    │    ├─■──lecture_lettre_lu_livre_article ── Topic: 35
#      │    │    │    │    └─■──lettre_lettres_écrivis_frère_écrivit ── Topic: 30
#      │    │    │    └─père_frère_wesel_beau_famille
#      │    │    │         ├─frère_père_beau_confessai_pénétration
#      │    │    │         │    ├─■──frère_satisfactions_efforçait_retourné_bonnes ── Topic: 94
#      │    │    │         │    └─■──père_frère_beau_confessai_pénétration ── Topic: 28
#      │    │    │         └─wesel_père_famille_retournâmes_toute
#      │    │    │              ├─■──wesel_père_retournâmes_allâmes_parents ── Topic: 91
#      │    │    │              └─■──famille_alliés_père_chacun_toute ── Topic: 72
#      │    │    └─tante_oncle_belle_mère_cousine
#      │    │         ├─■──oncle_tante_cousine_belle_sœur ── Topic: 18
#      │    │         └─■──tante_belle_mère_ingratitudes_pardonner ── Topic: 38
#      │    └─berlin_vienne_larmes_cour_maison
#      │         ├─berlin_vienne_larmes_cour_maison
#      │         │    ├─larmes_yeux_pouvais_vinrent_retenir
#      │         │    │    ├─■──larmes_yeux_vinrent_retenir_répandis ── Topic: 9
#      │         │    │    └─■──larmes_yeux_morte_versa_torrents ── Topic: 29
#      │         │    └─berlin_vienne_cour_maison_mari
#      │         │         ├─mari_époux_maison_chambre_lit
#      │         │         │    ├─maison_chambre_lit_chambres_vis
#      │         │         │    │    ├─■──lit_chambre_filles_porte_couchait ── Topic: 33
#      │         │         │    │    └─■──maison_chambre_chambres_salle_étage ── Topic: 11
#      │         │         │    └─mari_époux_mariage_femme_maris
#      │         │         │         ├─■──mari_époux_mariage_femme_maris ── Topic: 6
#      │         │         │         └─■──époux_mari_demeurerait_enveloppa_mariépoux ── Topic: 88
#      │         │         └─berlin_vienne_cour_prince_prusse
#      │         │              ├─berlin_vienne_cour_prusse_faire
#      │         │              │    ├─■──surpris_fait_demanda_voulut_croire ── Topic: 7
#      │         │              │    └─berlin_vienne_prusse_cour_roi
#      │         │              │         ├─■──air_assura_dame_fille_voulut ── Topic: 2
#      │         │              │         └─berlin_vienne_prusse_cour_roi
#      │         │              │              ├─■──roi_lettre_faire_jour_madame ── Topic: 0
#      │         │              │              └─■──berlin_vienne_prusse_cour_königsberg ── Topic: 1
#      │         │              └─prince_impératrice_eugène_cour_reine
#      │         │                   ├─impératrice_cour_reine_empereur_princesse
#      │         │                   │    ├─■──cour_ville_bonheur_dames_habit ── Topic: 62
#      │         │                   │    └─■──impératrice_reine_empereur_princesse_comtesse ── Topic: 10
#      │         │                   └─■──prince_eugène_avellino_protection_savoie ── Topic: 23
#      │         └─religion_wergeau_enfants_enfant_changement
#      │              ├─wergeau_enfants_enfant_fils_chers
#      │              │    ├─wergeau_nb_madame_hominum_in
#      │              │    │    ├─■──nb_hominum_in_wergeau_madame ── Topic: 55
#      │              │    │    └─■──wergeau_rougit_madame_fidélité_domestique ── Topic: 37
#      │              │    └─enfants_enfant_fils_chers_wergeau
#      │              │         ├─■──enfant_wergeau_protégez_conservez_enfants ── Topic: 64
#      │              │         └─■──enfants_enfant_chers_fils_ans ── Topic: 15
#      │              └─religion_changement_religieuse_changer_sainte
#      │                   ├─religion_changement_religieuse_changer_cacher
#      │                   │    ├─■──religion_ignorer_changement_voulu_ajustée ── Topic: 85
#      │                   │    └─■──religion_changement_religieuse_asteure_changer ── Topic: 21
#      │                   └─■──religieuse_religion_avoué_moindre_osait ── Topic: 95
#      └─strattmann_comtesse_dieu_dönhoff_église
#           ├─dieu_église_catherine_joie_evêque
#           │    ├─savais_voulez_oui_discours_donc
#           │    │    ├─voulez_oui_donc_deviendrai_faites
#           │    │    │    ├─■──deviendrai_voulez_donc_devenir_stable ── Topic: 59
#           │    │    │    └─oui_voulez_faites_répliqua_faut
#           │    │    │         ├─■──oui_voulez_voudrez_faites_tenez ── Topic: 12
#           │    │    │         └─■──laissez_voyez_dire_répliqua_voulez ── Topic: 22
#           │    │    └─savais_discours_pouvais_ignorais_novice
#           │    │         ├─discours_mots_parole_entendre_paroles
#           │    │         │    ├─■──discours_mots_vertu_quelque_paroles ── Topic: 63
#           │    │         │    └─■──consternée_parole_entendre_décontenancée_ouvrais ── Topic: 90
#           │    │         └─savais_ignorais_pouvais_novice_aucune
#           │    │              ├─■──savais_ignorais_quel_mot_alliances ── Topic: 49
#           │    │              └─novice_impossible_pouvais_aversion_aucune
#           │    │                   ├─■──moquait_aucun_aversion_aucune_penchant ── Topic: 53
#           │    │                   └─■──dépeindre_impossible_divertissais_novice_pouvais ── Topic: 39
#           │    └─dieu_église_catherine_evêque_joie
#           │         ├─dieu_catherine_joie_grâce_doux
#           │         │    ├─catherine_joie_vanité_ennemis_reviens
#           │         │    │    ├─joie_vanité_idées_ambition_charmée
#           │         │    │    │    ├─joie_vanité_idées_ambition_passion
#           │         │    │    │    │    ├─fer_point_rien_pensée_aucunement
#           │         │    │    │    │    │    ├─■──chargerait_effaroucha_débats_inquièterai_mentais ── Topic: 86
#           │         │    │    │    │    │    └─■──fer_pensée_déconcerter_félicitai_aguerrir ── Topic: 87
#           │         │    │    │    │    └─joie_vanité_idées_ambition_passion
#           │         │    │    │    │         ├─joie_idées_passion_charmée_inexprimable
#           │         │    │    │    │         │    ├─■──joie_charmée_bonheur_voir_rougis ── Topic: 8
#           │         │    │    │    │         │    └─■──idées_passion_esprit_imagination_sublime ── Topic: 45
#           │         │    │    │    │         └─vanité_ambition_acquérir_emparèrent_ajustement
#           │         │    │    │    │              ├─■──vanité_ambition_emparèrent_ajustement_danse ── Topic: 78
#           │         │    │    │    │              └─■──acquérir_empire_suffisait_mérite_monde ── Topic: 100
#           │         │    │    │    └─féliciter_félicita_félicitations_compliments_acceptai
#           │         │    │    │         ├─■──félicitations_féliciter_acceptai_remerciements_accueil ── Topic: 50
#           │         │    │    │         └─■──félicita_consolation_féliciter_compliments_habilla ── Topic: 93
#           │         │    │    └─catherine_ennemis_reviens_vierge_article
#           │         │    │         ├─catherine_ennemis_reviens_vierge_article
#           │         │    │         │    ├─catherine_vierge_luthérien_protestants_confesseur
#           │         │    │         │    │    ├─catherine_vierge_confesseur_image_luc
#           │         │    │         │    │    │    ├─■──catherine_confesseur_vint_situation_marquait ── Topic: 40
#           │         │    │         │    │    │    └─■──vierge_image_luc_sainte_peint ── Topic: 103
#           │         │    │         │    │    └─luthérien_protestants_protestant_apôtre_chrétiens
#           │         │    │         │    │         ├─luthérien_protestants_protestant_luther_règne
#           │         │    │         │    │         │    ├─■──trop_concerterait_opposition_opposèrent_inattentions ── Topic: 101
#           │         │    │         │    │         │    └─■──luthérien_protestants_protestant_luther_règne ── Topic: 77
#           │         │    │         │    │         └─apôtre_chrétiens_vérité_christ_paraissent
#           │         │    │         │    │              ├─■──vérité_paraissent_preuves_authentiques_conséquemment ── Topic: 105
#           │         │    │         │    │              └─■──apôtre_chrétiens_christ_césar_utile ── Topic: 110
#           │         │    │         │    └─ennemis_reviens_article_narration_combattre
#           │         │    │         │         ├─ennemis_article_combattre_suite_narration
#           │         │    │         │         │    ├─■──ennemis_combattre_ennemi_armes_soutins ── Topic: 43
#           │         │    │         │         │    └─article_narration_minuties_suite_animosité
#           │         │    │         │         │         ├─■──article_narration_animosité_exemples_digression ── Topic: 68
#           │         │    │         │         │         └─■──mensonge_accusation_su_adoucissement_circonstanciées ── Topic: 76
#           │         │    │         │         └─reviens_reprends_sujet_continuai_reste
#           │         │    │         │              ├─■──reviens_reprends_continuai_sujet_narration ── Topic: 19
#           │         │    │         │              └─■──alla_ceci_passa_couché_embrouilla ── Topic: 44
#           │         │    │         └─femmes_hé_oh_ho_bleistiftmarginalie
#           │         │    │              ├─femmes_hé_oh_ho_bleistiftmarginalie
#           │         │    │              │    ├─■──ho_hé_oh_bleistiftmarginalie_ah ── Topic: 26
#           │         │    │              │    └─■──femmes_fausse_arrive_toutes_modestes ── Topic: 96
#           │         │    │              └─■──aveugles_aboutissent_bannissons_commettent_broutent ── Topic: 108
#           │         │    └─dieu_divine_doux_divin_loué
#           │         │         ├─■──dieu_divine_providence_volontés_âme ── Topic: 5
#           │         │         └─■──dieu_doux_jésus_gloire_loué ── Topic: 3
#           │         └─église_evêque_kraus_mgr_religieuses
#           │              ├─■──kraus_königsberg_religieuses_accomplirais_parlée ── Topic: 75
#           │              └─église_evêque_mgr_sermon_chapelle
#           │                   ├─■──evêque_mgr_église_évêché_monseigneur ── Topic: 24
#           │                   └─■──église_oratoire_religieuses_porte_réjouis ── Topic: 20
#           └─strattmann_comtesse_dönhoff_fièvre_madame
#                ├─heures_matin_partîmes_nuit_midi
#                │    ├─matin_partîmes_heures_midi_avril
#                │    │    ├─■──janvier_1718_février_1717_1710 ── Topic: 47
#                │    │    └─■──matin_heures_midi_lundi_arrivâmes ── Topic: 16
#                │    └─nuit_jours_près_heures_trois
#                │         ├─■──jours_passâmes_près_huit_semaines ── Topic: 65
#                │         └─nuit_dormir_sommeil_fatigue_repos
#                │              ├─■──dormir_dormant_pendant_endormir_sommeil ── Topic: 74
#                │              └─■──nuit_fatigue_extrêmes_inquiétudes_mal ── Topic: 58
#                └─strattmann_comtesse_dönhoff_fièvre_madame
#                     ├─fièvre_rire_dohna_chevaux_ministre
#                     │    ├─rire_ministre_pologne_dankelmann_gouverneur
#                     │    │    ├─ministre_dankelmann_pologne_gouverneur_monsieur
#                     │    │    │    ├─■──pologne_wackerbarth_envoyé_bourgrave_chapeau ── Topic: 41
#                     │    │    │    └─ministre_dankelmann_gouverneur_monsieur_secrétaire
#                     │    │    │         ├─■──dankelmann_monsieur_danckelmann_rire_procura ── Topic: 67
#                     │    │    │         └─■──ministre_gouverneur_secrétaire_controverse_chevalier ── Topic: 25
#                     │    │    └─rire_virmond_riant_virmont_mit
#                     │    │         ├─■──rire_riant_mit_mis_plaisants ── Topic: 32
#                     │    │         └─■──virmond_virmont_promener_couleur_dirait ── Topic: 70
#                     │    └─fièvre_dohna_chevaux_médecin_roi
#                     │         ├─fièvre_médecin_dîner_souper_repas
#                     │         │    ├─dîner_souper_repas_grossesse_guerre
#                     │         │    │    ├─guerre_hiver_fille_premier_première
#                     │         │    │    │    ├─guerre_environs_surprend_étonnement_château
#                     │         │    │    │    │    ├─■──surprend_alarma_frappa_dépita_embarrassait ── Topic: 79
#                     │         │    │    │    │    └─guerre_environs_château_beauté_bâtiment
#                     │         │    │    │    │         ├─■──guerre_empoisonner_spirituelles_déclariez_exécutée ── Topic: 104
#                     │         │    │    │    │         └─■──environs_château_beauté_bâtiment_jardins ── Topic: 84
#                     │         │    │    │    └─fille_hiver_première_neige_premier
#                     │         │    │    │         ├─fille_hiver_neige_première_premier
#                     │         │    │    │         │    ├─■──hiver_neige_froid_campagne_effectivement ── Topic: 66
#                     │         │    │    │         │    └─fille_première_premier_début_fois
#                     │         │    │    │         │         ├─■──fille_tendresse_désespérait_remuais_dent ── Topic: 69
#                     │         │    │    │         │         └─■──première_début_premier_fois_levai ── Topic: 54
#                     │         │    │    │         └─chère_sœur_porte_tabourets_portes
#                     │         │    │    │              ├─■──porte_tabourets_ouvrit_portes_mis ── Topic: 109
#                     │         │    │    │              └─■──sœur_chère_parle_ancêtres_estimerait ── Topic: 107
#                     │         │    │    └─dîner_souper_repas_grossesse_très
#                     │         │    │         ├─dîner_souper_repas_migraine_tête
#                     │         │    │         │    ├─migraine_tête_calamité_terrible_détours
#                     │         │    │         │    │    ├─■──calamité_détours_effectivement_auberges_conspirait ── Topic: 51
#                     │         │    │         │    │    └─■──migraine_tête_terrible_maux_désordre ── Topic: 92
#                     │         │    │         │    └─souper_repas_dîner_table_viande
#                     │         │    │         │         ├─souper_repas_dîner_viande_souffris
#                     │         │    │         │         │    ├─■──chagrin_souffris_désespoir_extrême_martyre ── Topic: 17
#                     │         │    │         │         │    └─■──souper_repas_dîner_soupe_table ── Topic: 14
#                     │         │    │         │         └─■──table_compagnie_desservi_commença_carême ── Topic: 83
#                     │         │    │         └─grossesse_enceinte_homme_avancée_très
#                     │         │    │              ├─priai_prières_courte_paraissait_prière
#                     │         │    │              │    ├─■──buste_dorure_filer_étendit_dessus ── Topic: 102
#                     │         │    │              │    └─■──priai_prières_prière_intercédai_disposa ── Topic: 98
#                     │         │    │              └─grossesse_enceinte_homme_avancée_très
#                     │         │    │                   ├─homme_très_savant_beaucoup_peur
#                     │         │    │                   │    ├─■──homme_savant_très_agréable_honnête ── Topic: 42
#                     │         │    │                   │    └─■──peur_craignais_beaucoup_trouvait_osais ── Topic: 46
#                     │         │    │                   └─grossesse_enceinte_avancée_miroir_œil
#                     │         │    │                        ├─■──miroir_fixèrent_yeux_visage_œil ── Topic: 57
#                     │         │    │                        └─■──grossesse_enceinte_avancée_affligeantes_exemptait ── Topic: 61
#                     │         │    └─fièvre_médecin_maladie_médecins_remède
#                     │         │         ├─■──fièvre_médecin_maladie_prit_malade ── Topic: 34
#                     │         │         └─■──médecin_remède_médecins_aidait_maladie ── Topic: 56
#                     │         └─chevaux_dohna_roi_freihan_fiscal
#                     │              ├─fiscal_promis_écus_promit_cent
#                     │              │    ├─fiscal_écus_cent_soixante_coûta
#                     │              │    │    ├─■──fiscal_commission_chargea_question_attendant ── Topic: 82
#                     │              │    │    └─■──écus_cent_soixante_coûta_dépense ── Topic: 71
#                     │              │    └─promis_promit_promesse_ordonnai_messes
#                     │              │         ├─■──promis_promesse_promit_exigée_remarquerai ── Topic: 60
#                     │              │         └─■──ordonnai_rendit_mettre_heducks_dedans ── Topic: 73
#                     │              └─chevaux_dohna_roi_freihan_bruit
#                     │                   ├─chevaux_dohna_roi_freihan_jeune
#                     │                   │    ├─chevaux_dohna_roi_jeune_thé
#                     │                   │    │    ├─■──chevaux_thé_postes_café_chariots ── Topic: 36
#                     │                   │    │    └─dohna_roi_jeune_feld_possession
#                     │                   │    │         ├─■──roi_officier_biens_rois_permission ── Topic: 31
#                     │                   │    │         └─■──dohna_jeune_feld_comtes_famille ── Topic: 52
#                     │                   │    └─freihan_achat_affaire_oublié_refusa
#                     │                   │         ├─■──freihan_achat_affaire_possession_conseils ── Topic: 81
#                     │                   │         └─■──oublié_refusa_ignorer_souvient_oublia ── Topic: 80
#                     │                   └─bruit_partout_courait_fatal_pire
#                     │                        ├─■──bruit_courait_partout_assises_façons ── Topic: 106
#                     │                        └─■──pire_frayeurs_dangereuse_assassiné_forêts ── Topic: 97
#                     └─strattmann_comtesse_dönhoff_madame_brean
#                          ├─strattmann_comtesse_dönhoff_madame_brean
#                          │    ├─■──dönhoff_comtesse_partie_dohna_ottonette ── Topic: 13
#                          │    └─■──strattmann_comtesse_madame_brean_rabutin ── Topic: 4
#                          └─■──brean_lep_jésuite_batthyány_consulté ── Topic: 99

# %% [markdown]
# ## License
# The teaching material is available at [https://github.com/DHGraz/clariah2025-dse-ml/tree/main/materials](https://github.com/DHGraz/clariah2025-dse-ml/tree/main/materials) under the creative commons license **CC-BY-NC**.
# Please cite the notebooks and presentation by attributing the author and the GitHub repository.
