# %% [markdown]
# # A very basic introduction/brush up to Python
#
# - **Teacher** : Gunter Vasold
# - **Email**: gunter.vasold@uni-graz.at

# %% [markdown]
# ![Lizenz](images/CCLogo.png)

# %% [markdown]
# ## What is programming?
#
# * Problem solving
# * Instructing the computer "what to do" - writing a set of instructions to be interpreted by the computer (imperative programming)
# * A new type of literacy and personal expression, valuable to everyone, much like learning how to write
# * A new way to organize, express and share ideas
#
#
# Programming, at its core, is dealing with data. This includes reading (inputting), processing and writing (outputting) data.

# %% [markdown]
# ![Processing of data](data:image/png;base64,...
# )

# %% [markdown]
# ## Why Python?
#
#
# - High level, general-purpose programming language
# - Easy to learn
# - Easy to read
# - One of the most popular programming languages, for many usages - research and industry (Pinterest, YouTube, Google, Instagram...)

# %% [markdown]
# # Variables, Operators and Datatypes

# %% [markdown]
# ## Variables
#
# Explanation: A variable is a "container" for storing values.
#
# So: a variable is a name that we give (we define it ourselves) that points to a certain value.

# %% [markdown]
# ![Variables](data:image/png;base64,...)

# %% [markdown]
# This gives us the possibility to reference it and use it in various places in the program by simply using its name.
# This is practical because we can create a value in one place (code line) and use it in other places (lines).

# %%
greeting = 'Hello world!'

# %%
print(greeting)

# %% [markdown]
# Since we have to or can assign variable names ourselves, we should try to find good names for our variables from the beginning. Here are a few tips:
#
# * A variable name should be a noun (`firstname`, `score`). Only for boolean variables (`true/false`) it is often better to use a name starting with `is` or `has` (e.g. `is_student`, `has_payed`).
# * Variable names should be as meaningful as possible. If you need to understand your code again in a few weeks (e.g. to fix a bug), you will be grateful if a variable is called `firstname` instead of `n1` (or even worse: `x`).
# * It is highly recommended to use English words as variable names. The only exception to this rule is if you are 100% convinced that no one else will ever see your source code, which is really only true for scripts that you know will run exactly once and then be deleted. To the point: Use English identifiers from the beginning!
# * Variable names should start with a lowercase letter (`firstname` and not `Firstname`)
#
#
# ### Snakes or camels?
#
# Compound words are usually good (because easy to follow) names (`max_num_of_participants`). Two ways have been developed to improve the readability of such names:
#
#   * Snake style: `max_num_of_participants`. This form is recommended by the official [Style Guide for Python Code](https://www.python.org/dev/peps/pep-0008/).
#   * CamelCase Style: `maxNumOfParticipants`. This form is preferred by other programming languages (e.g. Java or JavaScript).
#
# Which form they use is up to them (often this is also dictated by the project if multiple people are involved, to keep the code consistent). The only important thing is that you stick to it consistently. That said, I would suggest that we stick to snake style for the exercises in this course as per the Python Style Guide.

# %%
age = 29
is_teacher = True
name = 'Anna'

# %%
print(age)
print(is_teacher)
print(name)

# %%
name

# %% [markdown]
# **Exercise 1**
#
# Create a variable named *score* and assign it a 3 digit number. Then create a second variable named 'firstname' and asign it your first name. The print out the values of your two variables.

# %%
score = 123
firstname = "Gunter"
print(score, firstname)

# %% [markdown]
# ## Operators
#
# <b> Some common types of operators in Python are: </b>
# * assignment operators
# * comparison operators
# * arithmetic (math) operators
#
#
# ### Assignment operators
# Assignment operators are used to assign values to variables, and we've aleady used the most important assignment operator, which is `=`.

# %%
programming_language = 'Python'

# %% [markdown]
# ### Comparison operators
#
# Comparison operators are used to compare two values.
#
# For example, one can test whether two values are equal. The corresponding operator is `==` (two equal characters!). Each comparison returns a truth value (i.e. `True` or `False`).

# %%
123 == 123

# %%
'Graz' == 'Vienna'

# %% [markdown]
# Of course you can also compare calculated values with each other:

# %%
100 / 4 == 75 / 3

# %% [markdown]
# And we can of cause compare variables (as they are only names for values):

# %%
population_2020 = 256871
population_2024 = 278461

population_2020 == population_2024

# %% [markdown]
# Python knows a number of comparison operators:
#
#   * `==` returns `True` if the two values are the same.
#   * `!=` returns `True` if the two values are different
#   * `<` returns `True` if the left value is smaller than the right value
#   * `<=` returns `True` if the left value is less than or equal to the right value
#   * `>` returns `True` if the left value is greater than the right value
#   * `>=` returns `True` if the left value is greater than or equal to the right value

# %%
'abc' != 'def'

# %%
5 > 4

# %% [markdown]
# ### Arithemtic operators
#
# We all know arithemtic operators from primary school:
#
# * `+`: addition
# * `-`: subtraction
# * `*`: multiplication
# * `/`: division

# %%
1 + 2 * 3

# %%
counter = 1
counter = counter + 1
print(counter)

# %% [markdown]
# The last example is usually written in this (more compact) way using the `+=` operator:

# %%
counter = 1
counter += 1
print(counter)

# %% [markdown]
# #### More arithemtic operators
#
# Python knows some more arithemtic operators:
#
# * `**`: exponentiation (``2 ** 8`` stands for 2 to the power of 8)
# * `%`: modulus (remainder of a division: ``5 % 2`` is 1)

# %%
2 ** 8

# %%
5 % 2

# %% [markdown]
# ## Data types
#
# Like in most programming languages, in Python each value has a specific **data type**. This **type** defines how the data is stored, what can be done with data and even which operators are supported and how they work.
#
# Some examples:
#
# * name - usually a string of characters
# * age - usually a number (integer)
# * the amount of money in your bank account - usually a value measured in e.g. euros, that has a fractional part (500.02)

# %% [markdown]
# ### Common data types

# %% [markdown]
# The most common data types in Python are:
#
#   * `int`: A number without fraction (`42`)
#   * `float`: A number with fraction (`3.14`)
#   * `str`: String. A sequence of characters: `"Python is nice"`
#   * `bool`: `True` or `False`
#   * `NoneType`: A special data type with only one value: `None`. This is used if a variable does not have a value, yet. In other languages you might know this als `null`.

# %% [markdown]
# Use the `type()` function to find out which data type a value (literal or variable) has:

# %%
type(2)

# %%
name = 'Otto'
type(name)

# %% [markdown]
# Als we've learned just before, the data type defines which operators are supported and how they work for a specific type:

# %%
1 + 1

# %%
'a' + 'b'

# %%
6 / 3

# %%
'Otto' / "x"

# %% [markdown]
# ### Converting types
#
# We can turn one type into another using specific functions (this is called type casting). What happens in the background is, that a new value with a different type is created from the old value.

# %%
1 + int(3.14)

# %%
str(1) + '2'

# %% [markdown]
# Casting a string to a numeric value like `float` or `int` of course only works for numerals:

# %%
1 + int('2')

# %%
1 + int('one')

# %% [markdown]
# ### Sequence types
#
# Python has some sequential datatypes which have in common, that they contain values in a defined sequence. Examples for such 'sequence type' are
#
# * strings
# * lists
# * tuples
#
# Although they are different data types, they can, as we will see, be used in very similar ways.

# %% [markdown]
# ### Strings
#
# Strings (data type `str`) are sequences of characters. If a literal value starts and ends with either `'` or `"`, python will create it as string:

# %%
sentence = "Python is a nice language"
type(sentence)

# %% [markdown]
# `len()` can be used to find out the number of characters in the string:

# %%
len(sentence)

# %% [markdown]
# #### String indexing
#
# We can address individual items (characters) over their index. In a sequential type, each item  has a unique index. Please note that the index starts at 0.

# %% [markdown]
# ![A string with index numbers](data:image/png;base64,...)

# %%
string = 'A string.'
print(f"'{string[0]}'")
print(f"'{string[1]}'")

# %% [markdown]
# Python has a nice feature: Use negative index numbers to count from the end. `-1` means "last item" `-2` means "second-to-last entry" and so on.

# %%
print(string[-1])
print(string[-2])

# %% [markdown]
# #### String slicing (cutting a substring)
#
# By specifying two values separated by a colon (index of the first element to be sliced out and the first element that is no longer to be sliced out), you can extract a substring from a string:

# %%
print(string[0:3])

# %% [markdown]
# Omitting a value (but keeping the colon) means "from start" or "to end":

# %%
print(string[:4])
print(string[-3:])

# %% [markdown]
# **Exercise**
#
# Slice the `string` in a way that the result is `stri`.

# %% [markdown]
# #### String methods
#
# You can also use cool functions to play around with strings, like:
#
# - `find()`  - finds the index of the first occurance of an item in a string
# - `replace()` - replaces item(s) in a string
# - `upper()` - makes the string uppercase
# - `lower()` - makes the string lowercase
# - `split()` - Splits a string at any whitespace or a given substring into a list of strings.

# %%
string.find('g')

# %%
string.replace('s', 'z')

# %%
string.replace('A', 'Ein')

# %%
string.upper()

# %%
string.lower()

# %%
# split at any whitespace
string.split()

# %%
# split at any 'tr'
string.split('tr')

# %% [markdown]
# #### The in operator
#
# Strings, lists and other container-like data types (e.g. dictionaries) support the `in` operator to check, if an element is contained in the container.
# This can be used to test, if a character or substring is in a string:

# %%
'i' in sentence

# %% [markdown]
# #### String formatting
# The recommended way of formatting strings since Python 3.6 are so-called f-strings (*formatted string literals*). The great innovation here is that the variables or expressions can be written directly on the spot in the curly braces. f-Strings are indicated by a preceding `f`.

# %%
name = input('Input your name: ')
age = int(input('Input your age: '))
print(f'Hi {name}. you are approximately {age * 365.25} days old.')

# %% [markdown]
# **Exercise**
# Write a program that:
#   * Prompts for the input of a name
#   * Assigns this input to a variable
#   * Generates the following output:
#
#     ```
#     Your name is XYZ and consists of n characters.
#     It starts with X and ends with Z.
#     ```

# %% [markdown]
# ### Lists
#
# - A list is an ordered sequence of items.
# - It can contain elements of any type.
# - You can think of a list as a container that contains other items in a particular order. A list (`list`) is thus another *sequence type* that we will learn about
# - A list is enclosed by a pair of square brackets; entries are delimited by commas.

# %%
medieval_books = [
    "The Canterbury Tales",
    "Beowulf",
    "Divine Comedy",
    "The Decameron",
    "The Song of Roland",
    "Nibelungenlied",
]
type(medieval_books)

# %% [markdown]
# `len()` works the same way as it does with strings

# %%
len(medieval_books)

# %% [markdown]
# Indexing and slicing works the same way as they do with strings

# %%
medieval_books[0]

# %%
medieval_books[:3]

# %% [markdown]
# #### List methods
#
# Lists have datatype specific methods, which can e.g. be used to modify a list. So we can add a new element at the end of a list by using the `append()` method:

# %%
medieval_books.append('Historia Regnum Britanniae')

# %%
medieval_books

# %% [markdown]
# The `pop()` method removes the last element of the list and returns the value of this last element:

# %%
removed_element = medieval_books.pop()
print(f"Removed: {removed_element}")
medieval_books

# %% [markdown]
# #### Multidimensional lists
#
# As a list can contain any data type, we can of cause also store lists in a list. This might come in handy if we, for example, want to manage tabular data. In the next example we have list `temperatures`. Each element in this list is another list containing 3 `int` values. So each of the inner lists represents a day with 3 temperatures. On the first day, we measured 17 degrees in the morning, 28 at noon and 24 in the evening, the values for the second day are 18,31, 28 and so on.

# %%
temperatures = [
    [17, 28, 24],
    [18, 31, 28],
    [20, 35, 29]
]

# %% [markdown]
# To get all measured temperatures from the first day, we use this code:

# %%
temperatures[0]

# %% [markdown]
# To get the evening temperature of the first day (so the last element of the first day entry), we can use this syntax:

# %%
temperatures[0][-1]

# %% [markdown]
# To get the evening temperature of the first day, we want the last element of the first item. We can write this in this way:

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# Dictionaries, which in other programming languages are also called *Maps*, *Hashtables* or *Associative Arrays*, are one of the most important data types in Python. A dictionary is a data type which can be used to store any number of values under a given 'key'. As each key references exactly one value, every key can only exist once within a dictionary.

# %% [markdown]
# Let's create an empty dictionary:

# %%
latin_proverbs = {}

# %% [markdown]
# Now we can fill it up with keys and values:

# %%
latin_proverbs["Alea iacta est"] = "The die is cast"
latin_proverbs["Carpe diem"] = "Fish of the day"
latin_proverbs["Veni, vidi, vici"] = "I came, I saw, I conquered"

# %%
print(latin_proverbs)
type(latin_proverbs)

# %% [markdown]
# As soon as our dictionary has entries, we can use it to get specific values. If we'd like to get the English translation of a latin proverb
# we access it via its key (the latin proverb), like we would look up a Latin word in a printed dictionary:

# %%
latin_proverbs['Alea iacta est']

# %% [markdown]
# If we use a key, which is not in the dictionary, Python will throw a *KeyError*:

# %%
latin_proverbs['Errare humanum est']

# %% [markdown]
# There are several ways to circumvent this. We could use the `in` operator to check, if the key exists or we could use the `.get()` method, which will not lead to an error, but return `None` if the key does not exist:

# %%
print(latin_proverbs.get('Errare humanum est'))

# %% [markdown]
# We can even define a default value instead of `None`:

# %%
print(latin_proverbs.get('Errare humanum est', 'I do not know this proverb'))

# %% [markdown]
# ##### Overwriting values
#
# We can add new keys and values to a dictionary at any time. But be aware: If a key already exists in the dictionary, it the old value will be replace by the new one:

# %%
# show the old value
print(latin_proverbs['Carpe diem'])

# set a new value using an existing key
latin_proverbs['Carpe diem'] = 'Seize the day'
print(latin_proverbs['Carpe diem'])

# %% [markdown]
# Again:
#
# - In a dictionary
# each value is referenced by a key, which means each entry consists of a key and its associated value
# - A key can be used only once in a dictionary (it's unique). If used a second time, the original value is overwritten
# - Dictionaries are a very useful data structure, e.g. if you have to store (and retrieve very fast) a lot of values.

# %% [markdown]
# # Control structures

# %% [markdown]
# ## Conditions (if ... elif ... else)
#
# - In the program flow often depending on certain states (e.g. the current value of a variable or a user input) branches must be taken. This is realized by *conditions*.
#
# - The program checks before such a "branch" whether a condition is true or false, and then takes either one way or the other.
#
# The general form of a condition in Python (and most higher programming languages) looks like this:
#
# ~~~
# if CONDITION == True:
#     do something
# else: # CONDITION was not True
#     do something else
# ~~~
#
# Where `else` can be omitted.

# %%
age = int(input('Enter your age: '))

if age < 18:
    print("You are to young!")
else:
    print("Welcome")

# %% [markdown]
# Notice the indentation after the colon: All subsequent lines with the same identation are executed if the condition is true/false.

# %% [markdown]
# Conditions can be nested to test more than one case:

# %%
age = int(input('Enter your age: '))

if age < 18:
    print("You are too young!")
else:
    if age >= 40:
        print("You are too old!")
    else:
        print("Welcome")

# %% [markdown]
# Python allows us to avoid nesting to make this better understandable by using `elif`:

# %%
age = int(input('Enter your age: '))

if age < 18:
    print("You are too young!")
elif age >= 40:
    print("You are too old!")
else:
    print("Welcome")

# %% [markdown]
# ## Loops (for and while)
#
# When programming, one or more statements often need to be repeated. For example, for each element of a sequence (e.g. for each character of a string) do something. For this purpose the `for` loop is best suited
#
# ### The for loop
#
# The `for` loop goes element by element through a data type consisting of several elements and applies the code in the *loop body* to each element. The loop automatically terminates when there are no more elements left.
#
# In the following example, we output each character of a string by looping in a `for` loop. After the last character, the loop terminates.

# %%
sentence = "Ad astra per aspera"
for character in sentence:
    print(character)
print('loop has finished')

# %% [markdown]
# This construct (`for element in sequence`) works for all data types that are able to supply one element after the other (e.g. strings, lists, dictionaries). Here is an example für a list, wich is generated by the `split()` method (`split()`returns a list of strings):

# %%
for token in sentence.split():
    print(token)

# %% [markdown]
# `for` also works on so called generator functions. These are function, which yield one value after each other. An example for this is the `range()` function, which yields all numbers from a number range, set via parameters:

# %%
total_sum = 0
for num in range(1, 11):
    print(num)
    total_sum +=  num
print('---')
print(total_sum)

# %% [markdown]
# ### The while loop
#
# While the `for` loop iterates over all elements of a sequence (or, more generally, an iterable), the `while` loop checks a condition on each loop pass and terminates when that condition is no longer satisfied.
#
# In the following example, we use a counter (`i`), which is initialized with `0`. We then check in a `while` loop if the value of `i` is less than 3.
# As long as this condition is true, we execute the loop body, where we ask the user to enter a number, which then is added to the result. When the counter reaches 3 the condition is no longer true and the loop will stop. It is really important to increase the number inside the loop, otherweise we will end up in an `infinite loop`.

# %%
result = 0

i = 0
while i < 3:
    user_input = int(input('Enter a number: '))
    result += user_input
    i += 1

print(result)

# %% [markdown]
# We can break out of a loop (also works for `for` loops) by using `break`. Knowing this, we can alter our program, so that it will continue asking for numbers until the user enters `=`:

# %%
sum_of_inputs = 0

while True: # infinite loop
    user_input = input('Enter a number: ')
    if user_input == '=':
        break
    sum_of_inputs += int(user_input)

print(sum_of_inputs)

# %% [markdown]
# ### Nested loops
#
# You can nest two (or more - however, this is usually not recommended because it may create a huge number of loop passes) loops inside each other. This allows, for example, to combine all elements from 2 sequences. In the next example we create a multiplication table.
#
# *Notice*: For counters in loops the variable names ``i``, ``j`` and ``k`` have become common (which should not be used for anything else than counters!).

# %%
for i in range(1, 11):
    for j in range(1, 11):
        print(f'{i} x {j} = {i * j}')

# %% [markdown]
# Nesting loops leads to exponential run time behaviour, which easily lets the number loop iterations explode. You can try it out, by executing the next cell, then increasing the `loops_per_loop` valiable stepwise (eg. 100, 200, 300, ...) and execue it again.
# Ignore the `import time` for now.

# %%
import time

loops_per_loop = 500 # num of loops per loop

counter = 0
start_time = time.time()
for i in range(loops_per_loop):
    for j in range(loops_per_loop):
        for k in range(loops_per_loop):
            counter += 1
print(f"{counter} iterations in {time.time() - start_time} seconds.")

# %% [markdown]
# # 5. Files

# %% [markdown]
# *The next code cell will create a new file in the current directory. This is the most simple way to guarantee, that all of us have a file to play with. Just run the cell (no need to understand, what's happing, yet). Just run the cell.*

# %%
s = """ [EPILOGUS]. 
Nunc tibi sit regi pax et clementia Christi;  Tu, princeps orbis, sis Christi munere fortis,  Tu, dominus regni, vivas in pace perenni!
Sic vult Wipo tuus cum fido pectore servus.

IV. VERSUS WIPONIS AD MENSAM REGIS.
Regalis coetus sit in isto tempore laetus,  Quo lux in tenebris exoritur populis.  
Inter laetandum res suadet commemorandum,  Quod Deus est natus, filius ipse datus.  
Parva dedit Bethlehem de magno germine panem,  Qui satiare valet, quicquid ubique manet.  
Panem de caelo porrexit gratia mundo;  Panis adest vivus perpetuusque cibus.  
Fons salientis aquae diffusae pocula vitae:  Hinc quicumque bibet, non iterum sitiet.  
Mellis dulcedo per Christum fluxit Olympo,  Ut sapiant famuli delicias Domini.  
Bos renuit foenum, cum vidit nobile granum,  Et praesepe Dei praecavet os asini.  
Virgo Maria, vide, mirando talia ride,  Ex te per verbum cerne Deum genitum!  
Rex pie caelestis, nostris illabere festis;  Da fructum pacis, sicut ubique facis!  
Heinrico regi digneris propitiari,  Ut cum laetitia pertrahat officia.
 FINIS."""
with open('proverbia_wipo.txt', 'w') as f:
    f.write(s)
print('proverbia_wipo.txt has been (re-)created')

# %% [markdown]
# ### Reading from files
#
# Files can be opened, read from, overwritten and appended to.
#
# Before a file can be read from or written to, it must be opened with the `open()` function.
#
# `open()` expects at least one argument: The name (possibly with path) of the file
#
# Let's open our first file. For this we will use the `with` context manager, the most common way of managing files in Python:

# %%
with open('proverbia_wipo.txt', encoding='utf-8') as file:
    for line in file:
        print(line)

# %% [markdown]
# ### Useful file methods
#
# In the last example, we iterated over all lines of the opened file. The file object, which was returned by the `open()` function,
# provides some usefull methods:
#
# - ` read()` - read the entire file contents into a string
# - ` readlines()` - reads each line of the file as an element in a list
#
# Using `readlines()`, we can store each line of the file in a list and the use `len()` to count the number of elements (corresponding to the number of lines):

# %%
with open('proverbia_wipo.txt', encoding='utf-8') as fh:
    lines = fh.readlines()
print(len(lines))

# %% [markdown]
# To count the number of characters in the file we read the whole text into one string and use `len()` on this string:

# %%
with open('proverbia_wipo.txt', encoding='utf-8') as fh:
    text = fh.read()
print(len(text))

# %% [markdown]
# ### Writing to a file
#
# So far we have only read from files. To be able to write to a file, we need to open it in a special way. The `open()` function expects as second argument a string specifying how to open the file. If we do not specify, the default value `r` (for `read`) is assumed.
#
# ```
# with open('data/proverbia_wipo.txt', encoding='utf-8') as fh:
# ```
# leads to the same result as
#
# ```
# with open('data/proverbia_wipo.txt', 'r', encoding='utf-8') as fh:
# ```
#
#
# If we want to open a file for writing, we use `'w'` (for `write`) instead of `'r'` and the `write()` function.
#
# Like this, we create and write to a file:

# %%
text = "Audentes fortuna iuvat"
with open('proverbs.txt', 'w', encoding='utf-8') as fh:
    fh.write(text)

# %% [markdown]
# If we want to append to an existing file and not overwrite it, we use `'a'` (for `append`) instead of `'w'` ind the `write()` method.

# %%
text = "Tempus fugit"
with open('proverbs.txt','a', encoding='utf-8') as fh:
    fh.write(f'\n{text}')

# %% [markdown]
# <b>Digression: </b> The `/n` is used for adding a newline

# %% [markdown]
# ### Non text files
#
# All we have learned about files up to now is only valid für text files. If you have to deal with a non text file (eg. an image or a pdf), you have to open the file in `binary` mode, which will not give you a string, but a `bytes` sequence.

# %%
with open('img/function.png', 'rb') as f:
    data = f.read()
    print(type(data))

# %% [markdown]
# **Exercise**
#
#
# ---
#
#
# Read line by line from 'proverbia_wipo.txt'. Print out lines longer than 100 characters.

# %% [markdown]
# # Functions

# %% [markdown]
# *Functions* are procedures or, if you will, subroutines that are called from the main program
#
# <b>The advantages of using functions are</b>:
#
# * Functions are reusable: A function, once written, can be used multiple times in a program (or even from different programs).
# * Functions prevent redundancy: each functionality exists only once in the program. This makes the program easier to maintain and reduces error-proneness.
# * Functions structure the code, making it easier to understand.

# %% [markdown]
# ### Writing a function
#
# A function definition in Python starts with the keyword `def` (many other languages use `function` instead). After the `def` follows the name of the function. This should ideally be a verb, since a function always does something. The name of the function is terminated by a pair of round brackets and a colon. This is followed by the actual function body indented, which defines what the function does.
#
#
# ```
# def function_name([parameter 1, [parameter 2, [...]]]):
#     function body
#     [return value]
# ```
#
#
# You remember the function calls we used to make without actually knowing what we were doing?
#
# * `print()`
# * `open()`
# * `len()`
# * ...
#
# All these functions have be written by someone else and made available to us, so we can use them in our code.

# %% [markdown]
# But let's create a new function.
# We write a (naive) `count_tokens()` function, which counts the words in a text file:

# %%
def count_tokens(filename, encoding='utf-8'):
    with open(filename, encoding=encoding) as f:
        text = f.read()
    return len(text.split())

# %% [markdown]
# Now we can use this function in our code:

# %%
num_of_tokens = count_tokens('proverbia_wipo.txt')
print(num_of_tokens)

# %% [markdown]
# # Modules
#
#
# Modules are collections of functions written by other people (or you) that you can reuse inside of your code to perform certain things (previously made solutions for specific problems). Using existing modules makes your life much easier, because is saves time and many of these modules were written by talented programmers and are well tested.
#
# ## Why modules are useful:
# * to organize larger projects into several smaller source code files - through this parts of code that belong together are stored together in a .py file - a <b> module </b>
# * to make code more reusable, since modules can be imported selectively into new code
# * smaller scripts can be easily packed into single files
#
# * However, as soon as a program has more than a few hundred lines, we should split the code into several modules, also because this makes the code easier to test and maintain
#
# ## There's a lot of existing modules
# - Python's standard library is organized into modules (and packages that bundle multiple modules). The standard library is huge and provides many useful modules and packages (https://docs.python.org/3/library/index.html)
# - third-party libraries are also available as modules. These can be easily installed with programs like `pip`, `conda` or `uv`. Check https://pypi.org for existing third party libraries.

# %% [markdown]
# ## Import and use a module from the standard library
# Just to demonstrate, how useful modules are, we will import the `random` module from the Python Standard Library and use a function provided by this module:

# %%
import random

random_numbers = []

for i in range(1, 10001): # loop 10 000 times
    # Add a random int between 1 and 100
    random_numbers.append(random.randint(1, 1000))

# Compute the mean of all randomly generated numbers. If random works well, this should be a number close to 500.
print(sum(random_numbers) / len(random_numbers))

# %% [markdown]
# ## Modules and packages for NLP (Natural Language Processing)
#
# In the standard library, support for NLP is very limited. But there are many third party libraries, which can be installed and used easily.
#
# These libraries acount for a variety of common NLP(Natural Language Processing) tasks.
# Such as:
#   * *tokenization* - separating the text into smaller units (usually sentences or words words)
#   * *automatic summarization (extractive, abstractive)* - a process of shortening a set of data computationally, to
#     create a subset (a summary) that represents the most important or relevant information within the original content
#   * *POS (part-of-speech) tagging* - categorizing words in a text (corpus) in correspondence with a particular
#     part of speech, depending on the definition of the word and its context (e.g. noun phrase, noun, verb, preposition...)
#   * *sentiment analysis* automatic detection of sentiments, emotions, and opinions in textual data
#   * *Named Entity Recognition* identification of key information in the text and classification into a set of predefined categories
#     (e.g. person, place, organization)
#   * *Topic Modelling* - identifying most relevant terms / concepts of a text
#
# ### NLTK
#
# Natural Language Toolkit
#
# https://www.nltk.org/, https://pypi.org/project/nltk/
#
#   * a toolkit for computational linguistics in Python
#   * most popular for NLP(Natural Language Processing)
#   * provides corpora, lexical resources and libraries for all sorts of NLP tasks such as classification, tokenization, pasrsing, stemming, tagging, etc.
#
# ### Spacy
#
# https://spacy.io/, https://spacy.io/usage
#
#   * a library for advanced NLP in Python
#   * an industry standard
#   * offers models for a large variety of languages for taks such as tokenization, summarization, sentiment analysis, topic modelling, etc.
#
# ### Textblob
#
# https://textblob.readthedocs.io/en/dev/
#
#   * library for processing textual data
#   * offers  part-of-speech tagging, noun phrase extraction, sentiment analysis, classification, translation, and more

# %% [markdown]
# To use a module, we need to install it (using `pip` most often)

# %%
# !pip install nltk

# %% [markdown]
# After the module has been installed, we have to import it, before we can use it:

# %%
import nltk

# %% [markdown]
# Let's now tokenize our text `'proverbs.txt'`  into words using the `word_tokenize()` function from the nltk module:

# %%
nltk.download('punkt_tab')  # This is needed for tokenization and has to be installed once

# %%
with open('proverbs.txt', 'r', encoding='utf-8') as file:
        text = file.read()
        # Tokenize the text into sentences
        words = nltk.word_tokenize(text)
        for word in words:
            print(word)

# %% [markdown]
# # And that's all for now!
#
# For more on Python programming, visit my GitHub repository for my introductionary course on Python (german only):
#
# https://github.com/gvasold/gdp
#
# Lucija made a (slighly modified) English version of it:
#
# - https://github.com/lucijakrusic/IP23
#
# She also has a more advanced course:
#
# - https://github.com/lucijakrusic/programming2SS23
#
# There you can find more examples, explanations and things we didn't have time to cover today.
#
# Enjoy the rest of the workshop!

# %%
def goodbye():
  print('Thank you for your attention!')

goodbye()
